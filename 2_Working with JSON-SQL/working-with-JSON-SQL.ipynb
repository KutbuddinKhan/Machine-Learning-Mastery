# %%
import pandas as pd

# %% [markdown]
# <h3>Working with JSON

# %%
pd.read_json("F:/DATASETS/train.json")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
# Out:
#                              provider  \
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ANG  https://www.exchangerate-api.com
# ..                                ...
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ANG  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ZMW  https://www.exchangerate-api.com/docs/free
# ZWL  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# AED  https://www.exchangerate-api.com/terms  INR 2024-08-14
# AFN  https://www.exchangerate-api.com/terms  INR 2024-08-14
# ALL  https://www.exchangerate-api.com/terms  INR 2024-08-14
# AMD  https://www.exchangerate-api.com/terms  INR 2024-08-14
# ANG  https://www.exchangerate-api.com/terms  INR 2024-08-14
# ..                                      ...  ...        ...
# XPF  https://www.exchangerate-api.com/terms  INR 2024-08-14
# YER  https://www.exchangerate-api.com/terms  INR 2024-08-14
# ZAR  https://www.exchangerate-api.com/terms  INR 2024-08-14
# ZMW  https://www.exchangerate-api.com/terms  INR 2024-08-14
# ZWL  https://www.exchangerate-api.com/terms  INR 2024-08-14
#
#      time_last_updated   rates
# AED         1723593601  0.0438
# AFN         1723593601  0.8430
# ALL         1723593601  1.0900
# AMD         1723593601  4.6300
# ANG         1723593601  0.0213
# ..                 ...     ...
# XPF         1723593601  1.3000
# YER         1723593601  2.9800
# ZAR         1723593601  0.2160
# ZMW         1723593601  0.3120
# ZWL         1723593601  0.1640
#
# [162 rows x 7 columns]

# %% [markdown]
# <h3>Working with SQL

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="ecommerce",
    auth_plugin='mysql_native_password'
)

# %%
df = pd.read_sql_query("SELECT * FROM ecommerce.customers WHERE customer_state='SP'", conn)

# %%
df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 41741  f255d679c7c86c24ef4861320d5b7675  d111b06b6f3a2add0d2241325f65b5ca
# 41742  f5a0b560f9e9427792a88bec97710212  b3e53d18a997f27a3ffd16da497eaf58
# 41743  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 41744  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 41745  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# 0                         14409                 franca             SP
# 1                          9790  sao bernardo do campo             SP
# 2                          1151              sao paulo             SP
# 3                          8775        mogi das cruzes             SP
# 4                         13056               campinas             SP
# ...                         ...                    ...            ...
# 41741                     13500              rio claro             SP
# 41742                      7790                cajamar             SP
# 41743                      3937              sao paulo             SP
# 41744                      6764        taboao da serra             SP
# 41745                      6703                  cotia             SP
#
# [41746 rows x 5 columns]
